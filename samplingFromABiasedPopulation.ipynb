# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
mean_uofm = 155
sd_uofm = 5
mean_gym = 185
sd_gym = 5
gymperc = 0.3

totalPop = 40000

uofm_students = np.random.normal(mean_uofm, sd_uofm, int(totalPop*(1- gymperc)))
gym_sts = np.random.normal(mean_gym, sd_gym, int(totalPop * (gymperc)))

# %%
population = np.append(uofm_students, gym_sts)

# %%
plt.figure(figsize = (10,12))

plt.subplot(3,1,1)
sns.distplot(uofm_students)
plt.title("Gym Students")
plt.xlim([140, 200])

plt.subplot(3,1,2)
sns.distplot(gym_sts)
plt.title("Uofm Students")
plt.xlim([140, 200])

plt.subplot(3,1,3)
sns.distplot(population)
plt.title("Full population")
plt.xlim([140, 200])
# Out:
# (140, 200)

# %%
numberSamps = 5000
sampSize = 50

mean_distribution = np.empty(numberSamps)
for i in range(numberSamps):
    random_students = np.random.choice(population, sampSize)
    mean_distribution[i] = np.mean(random_students)
    
plt.figure(figsize = (10,8))

plt.subplot(2,1,1)
sns.distplot(population)
plt.title("Full population of UofM students")
plt.axvline(x= np.mean(population))
plt.xlim([140, 200])

plt.subplot(2,1,2)
sns.distplot(mean_distribution)
plt.title("Sampling Distribution of the Mean Weight of Gym Goers")
plt.axvline(x = np.mean(population))
plt.axvline(x = np.mean(mean_distribution), color="black")
plt.xlim([140, 200])

plt.show()

# %%
numberSamps = 5000
sampSize =3

mean_distribution = np.empty(numberSamps)
for i in range(numberSamps):
    random_students = np.random.choice(gym_sts, sampSize)
    mean_distribution[i] = np.mean(random_students)
    
plt.figure(figsize=(10,8))

plt.subplot(2,1,1)
sns.distplot(population)
plt.title("Full population of Uofm Students")
plt.axvline(x = np.mean(population))
plt.xlim([140,200])

plt.subplot(2,1,2)
sns.distplot(mean_distribution)
plt.title("Sampling Distribution of the Mean Weight of Gym Goers")
plt.axvline(x = np.mean(population))
plt.axvline(x = np.mean(gym_sts), color = "black")
plt.xlim([140,200])

plt.show()

# %%
numberSamps= 5000
sampSize = 3

mean_distribution = np.empty(numberSamps)
for i in range(int(numberSamps*.50)):
    random_students = np.random.choice(gym_sts, sampSize)
    mean_distribution[i] =np.mean(random_students)
    
for i in range(int(numberSamps*.50), numberSamps):
    random_students = np.random.choice(uofm_students, sampSize)
    mean_distribution[i] =np.mean(random_students)
    
plt.figure(figsize=(10,8))

plt.subplot(2,1,1)
sns.distplot(population)
plt.title("Full population of Uofm Students")
plt.axvline(x = np.mean(population))
plt.xlim([140,200])

plt.subplot(2,1,2)
sns.distplot(mean_distribution)
plt.title("Sampling Distribution of the Mean Weight of Gym Goers")
plt.axvline(x = np.mean(population))
plt.axvline(x = np.mean(mean_distribution), color = "black")
plt.xlim([140,200])

plt.show()

# %%
numberSamps= 5000
sampSize = 3

mean_distribution = np.empty(numberSamps)
for i in range(int(numberSamps*.70)):
    random_students = np.random.choice(gym_sts, sampSize)
    mean_distribution[i] =np.mean(random_students)
    
for i in range(int(numberSamps*.70), numberSamps):
    random_students = np.random.choice(uofm_students, sampSize)
    mean_distribution[i] =np.mean(random_students)
    
plt.figure(figsize=(10,8))

plt.subplot(2,1,1)
sns.distplot(population)
plt.title("Full population of Uofm Students")
plt.axvline(x = np.mean(population))
plt.xlim([140,200])

plt.subplot(2,1,2)
sns.distplot(mean_distribution)
plt.title("Sampling Distribution of the Mean Weight of Gym Goers")
plt.axvline(x = np.mean(population))
plt.axvline(x = np.mean(mean_distribution), color = "black")
plt.xlim([140,200])

plt.show()
